# %%
# =======================================================================================
#  1. SETUP: Install Dependencies
# =======================================================================================
import os
import sys

# --- Change directory to project root ---
current_dir = os.path.abspath(os.getcwd())
while not os.path.exists(os.path.join(current_dir, 'requirements.txt')):
    parent_dir = os.path.dirname(current_dir)
    if parent_dir == current_dir:
        raise FileNotFoundError("Could not find the project root containing 'requirements.txt'.")
    current_dir = parent_dir
os.chdir(current_dir)
print(f"Changed working directory to project root: {os.getcwd()}")

# %%
# --- Install required packages---
print("\nInstalling packages from requirements.txt...")

# %pip install -r requirements.txt

conda install -c conda-forge graph-tool

# %%
print("Verifying package installations...")
try:
    import numpy
    import pandas
    import matplotlib
    from graph_tool.all import Graph
    print("✅ All packages are installed correctly.")
except ImportError as e:
    print(f"❌ Verification failed: {e}")
    print("Please check the installation steps above.")
